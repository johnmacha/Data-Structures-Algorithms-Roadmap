# %%
# poem.txt Contains famous poem "Road not taken" by poet Robert Frost. 
# You have to read this file in python and print every word and its count

class HashTable():
    def __init__(self):
        self.MAX = 200
        self.arr = [[] for i in range(self.MAX)]
    
    def gethash(self, key):
        h = 0
        for char in key:
            h += ord(char)
        return h % self.MAX
    
    def __setitem__(self, key, val):
        h = self.gethash(key)

        for idx, element in enumerate(self.arr[h]):
            if element[0] == key:
                self.arr[h][idx] = (key, val)
                return
            
        self.arr[h].append((key, val))
    
    def __getitem__(self, key):
        h = self.gethash(key)
        for element in self.arr[h]:
            if element[0] == key:
                return element[1]
        return None

# %%
my_poem = HashTable()
with open('./poem.txt', 'r') as f:
    for line in f:
        word, count = line.strip().split(',')
        my_poem[word] = count# use __setitem__() method
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 with open('./poem.txt', 'r') as f:
#       3     for line in f:
# ----> 4         word, count = line.strip().split(',')
#       5         my_poem[word] = count# use __setitem__() method
#
# ValueError: not enough values to unpack (expected 2, got 1)
